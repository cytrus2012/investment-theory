# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\km663\OneDrive\Documents\Uni\Masters\Python\Prices_all_companies.xlsx')

# %%
df=df.rename(columns={'G3':'Date'})

# %%
df
# Out:
#           Date        Nike         IBM      Target      Amazon       Apple  \
# 0   2000-12-29   47.719234   47.719234   21.383045    0.778125    0.226799
# 1   2001-01-31   62.877121   62.877121   25.182270    0.865625    0.329717
# 2   2001-02-28   56.084137   56.084137   25.858574    0.509375    0.278258
# 3   2001-03-30   54.057247   54.057247   23.958488    0.511500    0.336501
# 4   2001-04-30   64.713585   64.713585   25.532255    0.789000    0.388646
# ..         ...         ...         ...         ...         ...         ...
# 236 2020-08-31  105.286278  105.286278  145.662048  172.548004  127.271416
# 237 2020-09-30  105.246193  105.246193  152.393799  157.436493  114.428688
# 238 2020-10-30   96.587410   96.587410  147.359833  151.807495  107.561577
# 239 2020-11-30  106.846474  106.846474  173.797852  158.401993  117.630043
# 240 2020-12-31  110.466843  110.466843  171.600067  162.846497  131.330000
#
# ...

# %%
from itertools import islice

# %%
count = 0
df1 = pd.DataFrame()
for m in islice(df, 1, None):
    a = [np.nan]
    for i in df[m]:
        count = count + 1
        if count > 1:
            r = ((i/n)-1)*100
            a.append(r)
        n = i
    df1[m,' ER'] = a
    count = 0
    del n

# %%
df1
# Out:
#      (Nike,  ER)  (IBM,  ER)  (Target,  ER)  (Amazon,  ER)  (Apple,  ER)  \
# 0            NaN         NaN            NaN            NaN           NaN
# 1      31.764732   31.764732      17.767465      11.244980     45.378507
# 2     -10.803586  -10.803586       2.685636     -41.155235    -15.607021
# 3      -3.614017   -3.614017      -7.347992       0.417178     20.931294
# 4      19.713061   19.713061       6.568724      54.252199     15.496239
# ..           ...         ...            ...            ...           ...
# 236     0.300974    0.300974      20.122356       9.046103     21.437997
# 237    -0.038072   -0.038072       4.621486      -8.757859    -10.090819
# 238    -8.227170   -8.227170      -3.303262      -3.575409     -6.001214
# 239    10.621533   10.621533      17.941130       4.343987      9.360653
# 240     3.388384    3.388384      -1.264564       2.805838     11.646648
#
#      (Boeing,  ER)  (JP Morgan Chase,  ER)  (Procter & Gamble,  ER)  \
# ...

# %%
freerisk = pd.read_excel(r'C:\Users\km663\OneDrive\Documents\Uni\Masters\Python\freerisk-rate.xlsx')

# %%
freerisk['RF Percentage'] = freerisk['RF Percentage']*100

# %%
df2 = df1.sub(freerisk['RF Percentage'], axis=0)

# %%
df2
# Out:
#      (Nike,  ER)  (IBM,  ER)  (Target,  ER)  (Amazon,  ER)  (Apple,  ER)  \
# 0            NaN         NaN            NaN            NaN           NaN
# 1      31.224732   31.224732      17.227465      10.704980     44.838507
# 2     -11.183586  -11.183586       2.305636     -41.535235    -15.987021
# 3      -4.034017   -4.034017      -7.767992      -0.002822     20.511294
# 4      19.323061   19.323061       6.178724      53.862199     15.106239
# ..           ...         ...            ...            ...           ...
# 236     0.290974    0.290974      20.112356       9.036103     21.427997
# 237    -0.048072   -0.048072       4.611486      -8.767859    -10.100819
# 238    -8.237170   -8.237170      -3.313262      -3.585409     -6.011214
# 239    10.611533   10.611533      17.931130       4.333987      9.350653
# 240     3.378384    3.378384      -1.274564       2.795838     11.636648
#
#      (Boeing,  ER)  (JP Morgan Chase,  ER)  (Procter & Gamble,  ER)  \
# ...

# %%
df2.mean(axis = 0)
# Out:
# (Nike,  ER)                0.486956
# (IBM,  ER)                 0.486956
# (Target,  ER)              1.039707
# (Amazon,  ER)              2.914783
# (Apple,  ER)               3.117726
# (Boeing,  ER)              1.000038
# (JP Morgan Chase,  ER)     0.927600
# (Procter & Gamble,  ER)    0.734874
# (Coca-Cola ,  ER)          0.480782
# (Walt Disney,  ER)         1.020458
# dtype: float64
